# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer

# %%
data=pd.read_csv("https://raw.githubusercontent.com/K-C-Lalitha/predictDataset/main/predictDataset.csv")
data
# Out:
#                Name Gender
# 0             aayam      m
# 1           isabeth      f
# 2      girish kumar      m
# 3           sherrye      f
# 4              acer      m
# ...             ...    ...
# 85199      romonica      f
# 85200  charan singh      m
# 85201         billa      f
# 85202        jozyah      m
# 85203      kandence      f
#
# [85204 rows x 2 columns]

# %%
X = data['Name']  # Replace with the actual column name for the text data
y = data['Gender']

# %%
y=y.map({'m':0, 'f':1})

# %%
vectorizer = CountVectorizer(analyzer='char', ngram_range=(2, 4))
X = vectorizer.fit_transform(X)

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
svm_model= SVC(kernel='linear', C=1.0)

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8835771848838119
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88     12872
#            1       0.89      0.88      0.88     12690
#
#     accuracy                           0.88     25562
#    macro avg       0.88      0.88      0.88     25562
# weighted avg       0.88      0.88      0.88     25562
#
#
# Confusion Matrix:
#  [[11432  1440]
#  [ 1536 11154]]

# %%
import pickle
with open('svm.pkl', 'wb') as file:
    pickle.dump(svm_model, file)
